# %% [markdown]
# # 1. 라이브러리 설치

# %%
# %pip install gensim -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip list | grep numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'grep'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# %pip install konlpy -q
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # 2. 필요한 라이브러리 import

# %%
from gensim.models.word2vec import Word2Vec
from konlpy.tag import Okt  # 형태소 분석기
# 문자열 정리를 위해 정규 표현식 라이브러리 사용
import re

# %% [markdown]
# # 3. 데이터 수집
#
# 대한민국헌법.txt 파일 업로드

# %%
with open("대한민국헌법.txt", encoding='UTF-8') as f:
	content = f.read()

print(len(content)) # 20445글자로 이루어진 문서
# Out:
# 20445

# %% [markdown]
# # 4. 데이터 전처리 - 문장에서 불필요한 문자 제거

# %%
# 데이터 정리
print("[정리 전]\n", content[:100])

# 문장별로 분리하기 (한글 기준, '.', '?', '!' 뒤에 공백이 오거나 개행이 오는 경우 분리)
docs = re.split(r'(?<=[.?!])\s+', content.strip())

# 정규 표현식을 통한 한글 외 문자 제거
docs = [re.sub("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","", doc) for doc in docs]
print("-"*50)
print("[정리 후]\n", docs[:5]) # 정리 후 5개 문장 확인
# Out:
# [정리 전]
#  대한민국헌법
# [시행 1988. 2. 25.] [헌법 제10호, 1987. 10. 29., 전부개정]
# 전문
#
#
#        유구한 역사와 전통에 빛나는 우리 대한국민은 3ㆍ1운동으로
# --------------------------------------------------
# [정리 후]
#  ['대한민국헌법시행 ', '', ' 헌법 제호 ', '', ' 전부개정전문       유구한 역사와 전통에 빛나는 우리 대한국민은 운동으로 건립된 대한민국임시정부의 법통과 불의에 항거한 민주이념을 계승하고 조국의 민주개혁과 평화적 통일의 사명에 입각하여 정의인도와 동포애로써 민족의 단결을 공고히 하고 모든 사회적 폐습과 불의를 타파하며 자율과 조화를 바탕으로 자유민주적 기본질서를 더욱 확고히 하여 정치경제사회문화의 모든 영역에 있어서 각인의 기회를 균등히 하고 능력을 최고도로 발휘하게 하며 자유와 권리에 따르는 책임과 의무를 완수하게 하여 안으로는 국민생활의 균등한 향상을 기하고 밖으로는 항구적인 세계평화와 인류공영에 이바지함으로써 우리들과 우리들의 자손의 안전과 자유와 행복을 영원히 확보할 것을 다짐하면서 년 월 일에 제정되고 차에 걸쳐 개정된 헌법을 이제 국회의 의결을 거쳐 국민투표에 의하여 개정한다']

# %% [markdown]
# # 5. 데이터 전처리 - 문장을 단어로 분리(토큰화)

# %%
# 불용어(분석에 도움이 되지 않는 단어들) 목록을 미리 정의
# 예: 조사(의, 가, 이, 는, 등), 자주 등장하지만 의미가 적은 단어(좀, 잘 등)
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# %%
# 형태소 분석기 OKT를 사용하여 문장들을 형태소(단어 단위)로 나눌 준비
okt = Okt()

# 최종 토큰(단어)들을 모아둘 리스트
tokenized_data = []
# 각 문장(docs의 원소)에 대해 반복하면서 토큰으로 만듦
for sentence in (docs):
    # okt.morphs: 문장을 형태소(단어) 단위로 나눔
    # stem=True: 어간 추출(원형 복원) 수행
    tokenized_sentence = okt.morphs(sentence, stem=True)
    # 불용어 목록에 있는 단어들을 제거
    sentence = [word for word in tokenized_sentence if not word in stopwords]
    # 정제된 단어 리스트를 tokenized_data에 추가
    tokenized_data.append(sentence)
print(tokenized_data)
# Out:
# [['대한민국', '헌법', '시행'], [], ['헌법', '제호'], [], ['전부', '개정', '전문', '유구', '역사', '전통', '빛나다', '우리', '대', '국민', '운동', '건립', '되다', '대한민국', '임시정부', '법', '통과', '불의', '항거', '민주', '이념', '을', '계승', '하고', '조국', '민주', '개혁', '평화', '적', '통일', '사명', '입', '각하', '여', '정의', '인도', '동포', '애', '로써', '민족', '단결', '을', '공고', '히', '모든', '사회', '적', '폐습', '불의', '타파', '자율', '조화', '바탕', '자유민주', '적', '기', '본', '질서', '더욱', '확고하다',
조', '문체', '계', '버튼', '생활', '법령', '버튼', '제조', '모든', '국민', '법', '앞', '평등하다'], ['누구', '든지', '성별', '종교', '또는', '사회', '적', '신분', '의하다', '정치', '적', '경제', '적', '사회', '적', '문화', '적', '생활', '모든', '영역', '있다', '차별', '을', '받다', '아니다'], ['사회', '적', '특수', '계급', '제도', '인정', '되다', '아니다', '어떠하다', '형태', '로', '이르다', '창설', '수', '없다'], ['훈장', '등', '영전', '이르다', '받다', '에게만', '효력', '있다', '어떠하다', '특권', '따르다', '아니다'], ['조', '문체', '계', '버튼', '생활', '법령', '버튼', '제조', '모든', '국민', '신체', '자유', '가지다'], ['누구', '든지', '법률', '의하다', '아니다', '체포', '구속', '압수수색', '또는', '심문', '을', '받다', '아니다', '법률', '적법하다', '절차', '의하다', '아니다', '처벌', '보안처분', '또는', '강제', '노역', '을', '받다', '아니다'], ['모든', '국민', '고문', '을', '받다', '아니다', '형사', '상', '자기', '에게', '불리하다', '진술', '을', '강요', '당하다', '아니다'], ['체포', '구속', '압수', '또는', '수색', '을', '때', '에는', '적법하다', '절차', '따르다', '검사', '신청', '의하다', '법관', '발부', '영장', '을', '제시'], ['다만', '현행범인', '인', '경우', '장기', '년', '이상', '형', '해당', '죄', '범', '하고', '도피', '또는', '증거', '인', '멸', '염려', '있다', '때', '에는', '사후', '영장', '을', '청구', '수', '있다'], ['누구', '든지', '체포', '또는', '구속', '을', '당한', '때', '에는', '즉시', '변호인', '조력', '을', '받다', '권리', '가지다'], ['다만', '형사', '피고인', '스스로', '변호인', '을', '구', '수', '없다', '때', '에는', '법률', '정', '바', '의하다', '국가', '변호인', '을', '붙이다'], ['누구', '든지', '체포', '또는', '구속', '이유', '변호인', '조 ...

# %% [markdown]
# # 6. Word2Vector Model 활용
#
# 한글 토큰을 100차원의 워드 임베딩 벡터로 변환

# %%
# sentences: 학습에 사용할 토큰화된 문장들
# vector_size: 단어 벡터 차원 크기(100차원)
# window: 주변 단어를 고려하는 윈도우 크기(5)
# min_count: 최소 등장 횟수(1회 미만이면 무시)
# workers: 병렬 작업 쓰레드 수(4)
# sg: 0이면 CBOW 방식, 1이면 Skip-Gram 방식
model = Word2Vec(
    sentences = tokenized_data,
    vector_size = 100,
    window = 5,
    min_count = 1,
    workers = 4,
    sg = 0
)

# %%
# 가장 많은 빈도수를 보이는 단어 50개 출력
print(model.wv.index_to_key[:50])
# Out:
# ['을', '버튼', '제조', '계', '조', '문체', '법률', '되다', '있다', '정', '수', '대통령', '의하다', '국가', '또는', '국회', '아니다', '로', '국민', '헌법', '때', '관', '그', '에는', '받다', '생활', '법령', '바', '제', '모든', '위', '적', '없다', '가지다', '기타', '및', '필요하다', '사항', '장', '에서', '하', '인', '일', '권리', '임명', '의원', '선거', '정부', '안', '자유']

# %% [markdown]
# # 7. 불용어 정의 업데이트 및 코드 재 실행 후, 결과 확인​

# %%
# '을' 추가
stopwords = ['을', '의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']
tokenized_data = []
for sentence in (docs):
    tokenized_sentence = okt.morphs(sentence, stem=True)
    sentence = [word for word in tokenized_sentence if not word in stopwords]
    tokenized_data.append(sentence)

model = Word2Vec(
    sentences = tokenized_data,
    vector_size = 100,
    window = 5,
    min_count = 1,
    workers = 4,
    sg = 0
)

# %%
# 가장 많은 빈도수를 보이는 단어 50개 출력
print(model.wv.index_to_key[:50])
# Out:
# ['버튼', '제조', '계', '조', '문체', '법률', '되다', '있다', '정', '수', '대통령', '의하다', '국가', '또는', '국회', '아니다', '로', '국민', '헌법', '때', '관', '그', '에는', '받다', '생활', '법령', '바', '제', '모든', '위', '적', '없다', '가지다', '기타', '및', '필요하다', '사항', '장', '에서', '하', '인', '일', '권리', '임명', '의원', '선거', '정부', '안', '자유', '국무총리']

# %%
# "법률"이라는 단어가 학습된 100차원 벡터를 확인
print(model.wv.get_vector("법률"))
print(len(model.wv.get_vector("법률")))
# Out:
# [-0.00783046  0.0367409   0.0048953  -0.00640553 -0.00978795 -0.04488409
#   0.02735252  0.04518041 -0.02311657 -0.01023148 -0.02444712 -0.04326458
#  -0.01397551 -0.00215771  0.00271407 -0.02213803  0.00058265 -0.03874156
#  -0.00767009 -0.06724852  0.00827982  0.01948083  0.02044834 -0.00282213
#  -0.01428376  0.00523221 -0.03141983 -0.03925762 -0.01959109  0.0109532
#   0.0347783  -0.01164717  0.01034176 -0.0298731  -0.01271084  0.04333275
#   0.00603609 -0.00951237 -0.01778561 -0.05282651  0.02529759 -0.03480374
#  -0.00820428  0.00323856  0.01899155 -0.01413461 -0.02516096 -0.01174449
#   0.01897044  0.01495104  0.01089755 -0.03319009  0.01349166  0.01220436
#  -0.02607684  0.0238682   0.03209115 -0.01905528 -0.03348562 -0.00740767
#   0.02079772  0.00036441  0.00214801 -0.01281915 -0.02085812  0.0307121
#   0.00385471  0.02502336 -0.04415883  0.02476649 -0.02283702  0.02388348
#   0.04695504  0.00844173  0.03136768  0.02500326 -0.00565074  0.00114385
#  -0.03235859  0.00724416 -0.01178101 -0.00888763 -0.02299245  0.01763582
#  -0.00560012 -0.00015779  0.00446321  0.03476692  0.02688901  0.00927593
#   0.04691322  0.02801152 -0.01027422  0.00277278  0.04179444  0.02518299
#   0.00862532 -0.03065384  0.01031414 -0.00754188]
# 100

# %% [markdown]
# # 7. 코싸인 유사도 함수 헌법 및 적용

# %%
import numpy as np
from numpy import dot
from numpy.linalg import norm

# 코사인 유사도 함수
def cosine_similarity(A, B):
    return dot(A, B) / (norm(A) * norm(B))

# '법률'단어 벡터와 '헌법' 단어 벡터 간의 코사인 유사도 계산
similarity_value = cosine_similarity(model.wv.get_vector('법률'), model.wv.get_vector('헌법')                        )
print("'법률'과 '헌법'의 코사인 유사도:", similarity_value)  # 0.7452134
# Out:
# '법률'과 '헌법'의 코사인 유사도: 0.90256226

# %%
# 학습된 벡터 중, '헌법'과 가장 유사도가 높은 순으로 10개 단어를 출력
most_similar_words = model.wv.most_similar('헌법')
print("헌법과 유사한 단어 Top 10:", most_similar_words)
# Out:
# 헌법과 유사한 단어 Top 10: [('되다', 0.9275486469268799), ('의하다', 0.9270077347755432), ('제조', 0.9227799773216248), ('있다', 0.9225562810897827), ('위', 0.921949028968811), ('또는', 0.9209904670715332), ('관', 0.9139997959136963), ('및', 0.9079222679138184), ('국가', 0.9050745964050293), ('계', 0.9048219323158264)]
